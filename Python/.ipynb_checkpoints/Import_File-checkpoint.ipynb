# %%
import pandas as pd

import os
working_directory=os.getcwd()
print(working_directory)
# Out:
# /Users/naokimaruoka/Dropbox/00.Self-Dev/Programming/GitHub/Python

# %%
path=working_directory+'/Sample3.csv'
df_sample_data=pd.read_csv(path)

# %%
df_sample_data.head()
# Out:
#    No. Name Address Group  Money
# 0    1  Nae  11-222     A    999
# 1    2   Ao  11-223     C   2010
# 2    3   Tu  11-224     C     32
# 3    4   He  11-225     D  23231
# 4    5   Xo  11-226     E     -4

# %%
type(df_sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
df_sample_data
# Out:
#     No. Name Address Group   Money
# 0     1  Nae  11-222     A     999
# 1     2   Ao  11-223     C    2010
# 2     3   Tu  11-224     C      32
# 3     4   He  11-225     D   23231
# 4     5   Xo  11-226     E      -4
# 5     6   Ym  11-227     D    4444
# 6     7   Qw  11-228     B    2213
# 7     8   Tc  11-229     B   22222
# 8     9   Yb  11-229     E  432532
# 9    10   Nv  11-229     C     654
# 10   11   Cd  11-229     D       4

# %%
df_sample_data.head(2)
# Out:
#    No. Name Address Group  Money
# 0    1  Nae  11-222     A    999
# 1    2   Ao  11-223     C   2010

# %%
df_sample_data.tail(2)
# Out:
#     No. Name Address Group  Money
# 9    10   Nv  11-229     C    654
# 10   11   Cd  11-229     D      4

# %%
df_sample_data.sample(3)
# Out:
#    No. Name Address Group  Money
# 6    7   Qw  11-228     B   2213
# 0    1  Nae  11-222     A    999
# 4    5   Xo  11-226     E     -4

# %%
df_sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No.      11 non-null     int64
#  1   Name     11 non-null     object
#  2   Address  11 non-null     object
#  3   Group    11 non-null     object
#  4   Money    11 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 568.0+ bytes

# %%
df_sample_data.describe()
# Out:
#              No.          Money
# count  11.000000      11.000000
# mean    6.000000   44394.272727
# std     3.316625  129022.546513
# min     1.000000      -4.000000
# 25%     3.500000     343.000000
# 50%     6.000000    2010.000000
# 75%     8.500000   13333.000000
# max    11.000000  432532.000000

# %%
df_sample_data.describe()
# Out:
#              No.          Money
# count  11.000000      11.000000
# mean    6.000000   44394.272727
# std     3.316625  129022.546513
# min     1.000000      -4.000000
# 25%     3.500000     343.000000
# 50%     6.000000    2010.000000
# 75%     8.500000   13333.000000
# max    11.000000  432532.000000

# %%
df_sample_data.groupby(by='Group').mean().round()
# Out:
#        No.     Money
# Group
# A      1.0     999.0
# B      8.0   12218.0
# C      5.0     899.0
# D      7.0    9226.0
# E      7.0  216264.0

# %%
df_sample_mean=df_sample_data.groupby(by='Group').mean().round()

# %%
df_sample_mean.sort_values(by='Money',ascending=False)
# Out:
#        No.     Money
# Group
# E      7.0  216264.0
# B      8.0   12218.0
# D      7.0    9226.0
# A      1.0     999.0
# C      5.0     899.0

# %%
left=pd.DataFrame({'name':['aaa','bbb','ccc','ddd'],'age':[24,33,27,42]})
right=pd.DataFrame({'name':['eee','bbb','aaa','fff','ddd'],'group':['x','y','y','x','x']})

# %%
left
# Out:
#   name  age
# 0  aaa   24
# 1  bbb   33
# 2  ccc   27
# 3  ddd   42

# %%
right
# Out:
#   name group
# 0  eee     x
# 1  bbb     y
# 2  aaa     y
# 3  fff     x
# 4  ddd     x

# %%
pd.merge(left,right)
# Out:
#   name  age group
# 0  aaa   24     y
# 1  bbb   33     y
# 2  ddd   42     x

# %%
pd.merge(left,right,how='outer')
# Out:
#   name   age group
# 0  aaa  24.0     y
# 1  bbb  33.0     y
# 2  ccc  27.0   NaN
# 3  ddd  42.0     x
# 4  eee   NaN     x
# 5  fff   NaN     x

# %%
pd.concat([left,right])
# Out:
#   name   age group
# 0  aaa  24.0   NaN
# 1  bbb  33.0   NaN
# 2  ccc  27.0   NaN
# 3  ddd  42.0   NaN
# 0  eee   NaN     x
# 1  bbb   NaN     y
# 2  aaa   NaN     y
# 3  fff   NaN     x
# 4  ddd   NaN     x

# %%
pd.concat([left,right],axis=1) #横に結合
# Out:
#   name   age name group
# 0  aaa  24.0  eee     x
# 1  bbb  33.0  bbb     y
# 2  ccc  27.0  aaa     y
# 3  ddd  42.0  fff     x
# 4  NaN   NaN  ddd     x

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['font.family']='Arial Unicode MS'

# %%
df_sample_data[df_sample_data['Group']=='A']['Money'].plot(color=['skyblue','pink'])
# Out:
# <AxesSubplot:>
